# %% [markdown]
# Batch_generate defect types, later pass on to high-throughput MACE simulation.

# %%
from pymatgen.analysis.local_env import CrystalNN
from pymatgen.analysis.structure_prediction.dopant_predictor import (
    get_dopants_from_shannon_radii,
    get_dopants_from_substitution_probabilities
)
from pymatgen.ext.matproj import MPRester
from pymatgen.io.vasp import Poscar

num_dopants = 5 # n, p doping each 5

# %%
import os
import json
from tqdm import tqdm
import pandas as pd

directory = 'SM_dataset'  # Directory containing JSON files

def give_doping_recommendation(structure):
    structure.add_oxidation_state_by_guess()

    try: # try substitution probability first
        threshold = 1e-3  # probability threshold for substitution/structure predictions
        dopants = get_dopants_from_substitution_probabilities(
            structure, num_dopants=num_dopants, threshold=threshold
        )
    except ValueError: # if doesn't work here, e.g. alloys, try shannon radii matching
        try:
            cnn = CrystalNN()
            bonded_structure = cnn.get_bonded_structure(structure)
            dopants = get_dopants_from_shannon_radii(bonded_structure, num_dopants=num_dopants)
        except Exception as e:
            # if still doesn't work, for example single element compound have no oxidation number
            # then return nothing
            dopants = None
    return dopants

data_list = []

cnt = 0
for filename in tqdm(os.listdir(directory)):
    cnt += 1
    if cnt > 25:
        break
    # Construct the full path to the file
    file_path = os.path.join(directory, filename)
    
    # Open and read the JSON file
    with open(file_path, 'r') as file:
        data = json.load(file)
        structure_string = data["Structure_rlx"]
        ICSD = data["ICSD_number"]

    structure_string = '\n'+structure_string.split('\n', 1)[1]

    # Use pymatgen to parse the structure
    poscar = Poscar.from_str(structure_string, read_velocities=False)
    # poscar.write_file('./POSCAR')
    structure = poscar.structure
    if sum(poscar.natoms) >= 25:
        dopants = None
    else: # return a dictionary from pymatgen format
        dopants = give_doping_recommendation(structure)
    
    # convert to unified dataframe
    if dopants is not None:
        # Extract the first 5 dopants for n_doping and p_doping, if available
        n_dopants = [dopants['n_type'][i]['dopant_species'] if i < len(dopants['n_type']) else None for i in range(5)]
        n_originals = [dopants['n_type'][i]['original_species'] if i < len(dopants['n_type']) else None for i in range(5)]
        p_dopants = [dopants['p_type'][i]['dopant_species'] if i < len(dopants['p_type']) else None for i in range(5)]
        p_originals = [dopants['p_type'][i]['original_species'] if i < len(dopants['p_type']) else None for i in range(5)]
    else:
        n_dopants, n_originals = [None] * 5, [None] * 5
        p_dopants, p_originals = [None] * 5, [None] * 5
    
    data_list.append({
        "ICSD": ICSD,
        "Crystal": filename,
        "n_dopant": n_dopants,
        "n_original": n_originals,
        "p_dopant": p_dopants,
        "p_original": p_originals,
    })

df = pd.DataFrame(data_list)
# Out:
#   0%|          | 0/10476 [00:00<?, ?it/s]
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/io/vasp/inputs.py:462: BadPoscarWarning: Ignoring selective dynamics tag, as no ionic degrees of freedom were fixed.
#   warnings.warn(
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for O0+ with coordination number 7.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for Na0+ with coordination number 6.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
#   0%|          | 8/10476 [00:00<06:35, 26.47it/s]/home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for Cs0+ with coordination number 8.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for I0+ with coordination number 2.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for Cl0+ with coordination number 5.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:3951: UserWarning: CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.
#   warnings.warn(
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for Pd2+ with coordination number 2.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for Cs+ with coordination number 3.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for C2- with coordination number 5.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/core/periodic_table.py:1327: UserWarning: Specified spin='' not consistent with database spin of High Spin. Only one spin data available, and that value is returned.
#   warnings.warn(
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for S1.43- with coordination number 2.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for S1.43- with coordination number 1.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
#   0%|          | 17/10476 [00:01<12:55, 13.50it/s]/home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for Tl+ with coordination number 3.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for Sb2.67- with coordination number 4.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
# /home/vipandyc/miniconda3/envs/cava/lib/python3.10/site-packages/pymatgen/analysis/structure_prediction/dopant_predictor.py:104: UserWarning: Shannon radius not found for Sb2.67- with coordination number 7.
# Skipping...
#   warnings.warn(f"Shannon radius not found for {species} with coordination number {cn}.\nSkipping...")
#   0%|          | 25/10476 [00:01<11:15, 15.47it/s]

# %%
df.to_csv('Defect_combinations.csv')
df.to_pickle('Defect_combinations.pkl')
df.head(20)
# Out:
#       ICSD                   Crystal                        n_dopant  \
# 0    36626        Nb1O5P1_36626.json  [None, None, None, None, None]
# 1   195115      Bi1Cl1O1_195115.json         [F-, Cl-, K+, Rb+, Na+]
# 2    65183         I3O1W1_65183.json         [F-, Cl-, K+, Cs+, Rb+]
# 3   260890   Al2Ca2O9Sn2_260890.json  [None, None, None, None, None]
# 4   180558         Na2O2_180558.json  [None, None, None, None, None]
# 5   170946    Cl1Cu1H3N1_170946.json      [O2-, S2-, Se2-, F-, Zn2+]
# 6   262708      Cd1O3Ti1_262708.json     [F-, Ta5+, Cl-, Nb5+, Ge4+]
# 7     8097        Ca1O4Te1_8097.json     [F-, La3+, Cl-, Nd3+, Pr3+]
# 8    14260       Cl2Cs1I1_14260.json  [None, None, None, None, None]
# 9   609323     Al1Se2Tl1_609323.json  [None, None, None, None, None]
# 10   94396       C2Cs2Pd1_94396.json  [None, None, None, None, None]
# 11  423062          P2S7_423062.json   [S6+, Mn7+, Br7+, Cr6+, Cl7+]
# 12   31388     Ag1C4Co1O4_31388.json  [None, None, None, None, None]
# 13  100204         La2O3_100204.json       [F-, Cl-, Se4+, Br-, U4+]
# 14  251803  Ba2H1Mn1O9V2_251803.json  [None, None, None, None, None]
# 15  169667       Hg1O4W1_169667.json      [F-, Cl-, Ge4+, Sn4+, V3+]
# 16  409475     Ca5N4O2W1_409475.json        [O2-, S2-, Se2-, F-, F-]
# 17   15913       O2Sr1Zn1_15913.json     [F-, La3+, Si4+, Ge4+, Cl-]
# 18   76500      Cd3Sb3Tl2_76500.json    [I5+, Cf3+, Cd2+, I5+, Cf3+]
# 19   30503      Ag2H1O4P1_30503.json     [F-, Cl-, In3+, Ga3+, Cr6+]
#
#                         n_original                        p_dopant  \
# 0   [None, None, None, None, None]  [None, None, None, None, None]
# 1        [O2-, O2-, Cl-, Cl-, Cl-]        [O2-, S2-, Na+, K+, Rb+]
# 2           [O2-, O2-, I-, I-, I-]    [O2-, Cr3+, S2-, Pb2+, Mg2+]
# 3   [None, None, None, None, None]  [None, None, None, None, None]
# 4   [None, None, None, None, None]  [None, None, None, None, None]
# 5        [N3-, N3-, N3-, N3-, Cu+]      [O2-, S2-, O2-, O2-, Se2-]
# 6     [O2-, Ti4+, O2-, Ti4+, Cd2+]    [Na+, Na+, Zn2+, Mn2+, Mg2+]
# 7     [O2-, Ca2+, O2-, Ca2+, Ca2+]     [Na+, Re5+, K+, Ir5+, Co2+]
# 8   [None, None, None, None, None]  [None, None, None, None, None]
# 9   [None, None, None, None, None]  [None, None, None, None, None]
# 10  [None, None, None, None, None]  [None, None, None, None, None]
# 11       [P5+, P5+, P5+, P5+, P5+]    [C4+, B3+, Si4+, Be2+, Al3+]
# 12  [None, None, None, None, None]  [None, None, None, None, None]
# 13     [O2-, O2-, La3+, O2-, La3+]     [Sr2+, Ba2+, Na+, Ca2+, K+]
# 14  [None, None, None, None, None]  [None, None, None, None, None]
# 15    [O2-, O2-, Hg2+, Hg2+, Hg2+]      [Na+, Cu+, Re5+, K+, Ru5+]
# 16       [N3-, N3-, N3-, O2-, N3-]        [Na+, Na+, Re5+, K+, K+]
# 17    [O2-, Sr2+, Zn2+, Zn2+, O2-]        [Cs+, Rb+, K+, Na+, Cu+]
# 18     [Cd2+, Cd2+, Tl+, Tl+, Tl+]       [Na+, Li+, Li+, Ag+, Na+]
# 19       [O2-, O2-, Ag+, Ag+, P5+]     [Si4+, O2-, Ge4+, O2-, N3-]
#
#                         p_original
# 0   [None, None, None, None, None]
# 1     [Cl-, Cl-, Bi3+, Bi3+, Bi3+]
# 2          [I-, W5+, I-, W5+, W5+]
# 3   [None, None, None, None, None]
# 4   [None, None, None, None, None]
# 5         [Cl-, Cl-, Cu+, H+, Cl-]
# 6   [Cd2+, Ti4+, Ti4+, Ti4+, Ti4+]
# 7   [Ca2+, Te6+, Ca2+, Te6+, Te6+]
# 8   [None, None, None, None, None]
# 9   [None, None, None, None, None]
# 10  [None, None, None, None, None]
# 11       [P5+, P5+, P5+, P5+, P5+]
# 12  [None, None, None, None, None]
# 13  [La3+, La3+, La3+, La3+, La3+]
# 14  [None, None, None, None, None]
# 15      [W6+, Hg2+, W6+, W6+, W6+]
# 16     [W6+, Ca2+, W6+, W6+, Ca2+]
# 17  [Sr2+, Sr2+, Sr2+, Zn2+, Zn2+]
# 18  [Cd2+, Cd2+, Cd2+, Cd2+, Cd2+]
# 19        [P5+, Ag+, P5+, H+, Ag+]
